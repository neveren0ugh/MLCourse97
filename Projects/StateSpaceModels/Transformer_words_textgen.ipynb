# %%
import torch
import torch.nn as nn
import torch.optim as optim
import math
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from collections import Counter
from time import time

# %%
TRAIN_TEXT_FILE_PATH = 'text.txt'
BATCH_SIZE = 16
epochs = 20


with open(TRAIN_TEXT_FILE_PATH) as text_file:
    text_sample = text_file.readlines()[::2]
text_sample = ' '.join(text_sample)

words = text_sample.split()
word_counts = Counter(words)
vocab = list(word_counts.keys())
vocab_size = len(vocab)
word_to_int = {word: i for i, word in enumerate(vocab)}
int_to_word = {i: word for word, i in word_to_int.items()}
SEQUENCE_LENGTH = 64
samples = [words[i:i+SEQUENCE_LENGTH+1] for i in range(len(words)-SEQUENCE_LENGTH)]
print(vocab)
print(word_to_int)
print(int_to_word)
print(vocab_size)
# Out:
# ['Три', 'девицы', 'под', 'окном', '"Кабы', 'я', 'была', 'царица,-', 'То', 'на', 'весь', 'крещеный', 'мир', '-', 'бы', 'одна', 'Я', 'б', 'для', 'батюшки-царя', 'Только', 'вымолвить', 'успела,', 'И', 'в', 'светлицу', 'входит', 'царь,', 'Во', 'все', 'время', 'разговора', 'Речь', 'последней', 'по', 'всему', '"Здравствуй,', 'красная', 'девица,-', 'роди', 'богатыря', 'Вы', 'ж,', 'голубушки-сестрицы,', 'Поезжайте', 'вслед', 'за', 'мной,', 'Будь', 'из', 'вас', 'ткачиха,', 'В', 'сени', 'вышел', 'царь-отец.', 'Царь', 'недолго', 'собирался:', 'Салтан', 'пир', 'честной', 'А', 'потом', 'честные', 'гости', 'Положили', 'молодых', 'кухне', 'злится', 'повариха,', 'завидуют', 'оне', 'царица', 'молодая,', 'С', 'первой', 'ночи', 'понесла.', 'Салтан,', 'с', 'женой', 'простяся,', 'Ей', 'наказывал', 'себя', 'Между', 'тем,', 'как', 'он', 'далеко', 'Наступает', 'срок', 'родин;', 'над', 'ребенком,', 'Шлет', 'письмом', 'она', 'гонца,', 'ткачиха', 'поварихой,', 'Извести', 'ее', 'хотят,', 'Сами', 'шлют', 'гонца', 'другого', '"Родила', 'ночь', 'Не', 'мышонка,', 'не', 'лягушку,', 'Как', 'услышал', 'царь-отец,', 'гневе', 'начал', 'чудесить', 'Но,', 'смягчившись', 'сей', 'раз,', '"Ждать', 'царева', 'возвращенья', 'Едет', 'грамотой', 'гонец', 'поварихой', 'Обобрать', 'его', 'велят;', 'суму', 'пустую', 'привез', 'хмельной', '"Царь', 'велит', 'своим', 'боярам,', 'царицу', 'и', 'приплод', 'Делать', 'нечего:', 'бояре,', 'царице', 'молодой,', 'Объявили', 'царску', 'волю', 'Прочитали', 'вслух', 'указ', 'бочку', 'сыном', 'посадили,', 'пустили', 'Окиян', 'синем', 'небе', 'звезды', 'блещут,', 'Туча', 'небу', 'идет,', 'Словно', 'горькая', 'вдовица,', 'растет', 'ребенок', 'там', 'День.прошел', 'вопит...', '"Ты,', 'волна', 'моя,', 'волна?', 'Плещешь', 'ты,', 'куда', 'захочешь,', 'Топишь', 'берег', 'ты', 'земли,', 'губи', 'нашу', 'душу:', 'послушалась', 'волна:', 'Бочку', 'вынесла', 'легонько', 'Мать', 'младенцем', 'спасена;', 'Но', 'бочки', 'кто', 'их', 'вынет?', 'Сын', 'ножки', 'поднялся,', 'Понатужился', 'немножко:', 'Нам', 'проделать?"', 'молвил', 'он,', 'сын', 'теперь', 'воле;', 'Море', 'синее', 'кругом,', 'подумал:', 'добрый', 'ужин', 'Ломит', 'у', 'дуба', 'сук', 'Со', 'креста', 'снурок', 'шелковый', 'Тонку', 'тросточку', 'сломил,', 'пошел', 'край', 'долины', 'К', 'морю', 'лишь', 'подходит', 'Видно,', 'море', 'тихо:', 'Бьется', 'лебедь', 'средь', 'зыбей,', 'Та', 'бедняжка', 'так', 'плещет,', 'Тот', 'уж', 'когти', 'распустил,', 'раз', 'стрела', 'запела', 'Коршун', 'кровь', 'пролил.', 'Смотрит:', 'коршун', 'тонет', 'Лебедь', 'около', 'плывет,', 'Гибель', 'близкую', 'торопит,', 'царевичу', '"Ты', 'царевич,', 'мой', 'спаситель,', 'тужи,', 'что', 'меня', 'Что', 'пропала', 'море;', 'Отплачу', 'тебе', 'добром,', 'Ты', 'ведь', 'избавил,', 'коршуна', 'убил,', 'Ввек', 'тебя', 'забуду:', 'воротись,', 'Улетела', 'лебедь-птица,', 'Целый', 'день', 'проведши', 'так,', 'Вот', 'открыл', 'царевич', 'очи;', 'дивясь,', 'перед', 'собой', 'Стены', 'частыми', 'зубцами,', 'Блещут', 'маковки', 'церквей', 'Он', 'скорей', 'будит;', 'Говорит', 'он,-', 'вижу', 'я:', 'идут', 'ко', 'граду.', 'Оглушительный', 'трезвон', 'ним', 'народ', 'навстречу', 'валит,', 'колымагах', 'золотых', 'Все', 'громко', 'величают,', 'Княжей', 'шапкой,', 'главой', 'среди', 'своей', 'столицы,', 'тот', 'же', 'стал', 'княжить', 'Ветер', 'гуляет', 'бежит', 'себе', 'волнах', 'Корабельщики', 'дивятся,', 'На', 'знакомом', 'острову', 'Город', 'новый', 'златоглавый,', 'Пушки', 'пристани', 'палят,', 'Пристают', 'к', 'заставе', 'Их', 'кормит', 'поит', '"Чем', 'вы,', 'гости,', 'торг', 'ведете', 'ответ:', 'Торговали', 'соболями,', 'нам', 'срок,', 'Мимо', 'острова', 'Буяна,', 'Князь', 'им', 'вымолвил', 'тогда:', 'По', 'Окияну', 'От', 'ему', 'поклон".', 'берега', 'душой', 'печальной', 'Глядь', 'поверх', 'текучих', 'вод', 'князь', 'прекрасный!', 'Опечалился', 'чему?"', 'печально', 'отвечает:', 'Одолела', 'молодца:', 'князю:', '"Вот', 'чем', 'горе!', 'Полететь', 'кораблем?', 'крылами', 'замахала,', 'обрызгала', 'Тут', 'точку', 'уменьшилс ...
# {'Три': 0, 'девицы': 1, 'под': 2, 'окном': 3, '"Кабы': 4, 'я': 5, 'была': 6, 'царица,-': 7, 'То': 8, 'на': 9, 'весь': 10, 'крещеный': 11, 'мир': 12, '-': 13, 'бы': 14, 'одна': 15, 'Я': 16, 'б': 17, 'для': 18, 'батюшки-царя': 19, 'Только': 20, 'вымолвить': 21, 'успела,': 22, 'И': 23, 'в': 24, 'светлицу': 25, 'входит': 26, 'царь,': 27, 'Во': 28, 'все': 29, 'время': 30, 'разговора': 31, 'Речь': 32, 'последней': 33, 'по': 34, 'всему': 35, '"Здравствуй,': 36, 'красная': 37, 'девица,-': 38, 'роди': 39, 'богатыря': 40, 'Вы': 41, 'ж,': 42, 'голубушки-сестрицы,': 43, 'Поезжайте': 44, 'вслед': 45, 'за': 46, 'мной,': 47, 'Будь': 48, 'из': 49, 'вас': 50, 'ткачиха,': 51, 'В': 52, 'сени': 53, 'вышел': 54, 'царь-отец.': 55, 'Царь': 56, 'недолго': 57, 'собирался:': 58, 'Салтан': 59, 'пир': 60, 'честной': 61, 'А': 62, 'потом': 63, 'честные': 64, 'гости': 65, 'Положили': 66, 'молодых': 67, 'кухне': 68, 'злится': 69, 'повариха,': 70, 'завидуют': 71, 'оне': 72, 'царица': 73, 'молодая,': 74, 'С': 75, 'первой': 76, 'ночи': 77, 'понесла.': 78, 'Салтан,': 79, 'с': 80, 'женой': 81, 'простяся,': 82, 'Ей': 83, 'наказывал': 84, 'себя': 85, 'Между': 86, 'тем,': 87, 'как': 88, 'он': 89, 'далеко': 90, 'Наступает': 91, 'срок': 92, 'родин;': 93, 'над': 94, 'ребенком,': 95, 'Шлет': 96, 'письмом': 97, 'она': 98, 'гонца,': 99, 'ткачиха': 100, 'поварихой,': 101, 'Извести': 102, 'ее': 103, 'хотят,': 104, 'Сами': 105, 'шлют': 106, 'гонца': 107, 'другого': 108, '"Родила': 109, 'ночь': 110, 'Не': 111, 'мышонка,': 112, 'не': 113, 'лягушку,': 114, 'Как': 115, 'услышал': 116, 'царь-отец,': 117, 'гневе': 118, 'начал': 119, 'чудесить': 120, 'Но,': 121, 'смягчившись': 122, 'сей': 123, 'раз,': 124, '"Ждать': 125, 'царева': 126, 'возвращенья': 127, 'Едет': 128, 'грамотой': 129, 'гонец': 130, 'поварихой': 131, 'Обобрать': 132, 'его': 133, 'велят;': 134, 'суму': 135, 'пустую': 136, 'привез': 137, 'хмельной': 138, '"Царь': 139, 'велит': 140, 'своим': 141, 'боярам,': 142, 'царицу': 143, 'и': 144, 'приплод': 145, 'Делать': 146, 'нечего:': 147, 'бояре,': 148, 'царице': 149, 'молодой,': 150, 'Объявили': 151, 'царску': 152, 'волю': 153, 'Прочитали': 154, 'вслух': 155, 'указ': 156, 'бочку': 157, 'сыном': 158, 'посадили,': 159, 'пустили': 160, 'Окиян': 161, 'синем': 162, 'небе': 163, 'звезды': 164, 'блещут,': 165, 'Туча': 166, 'небу': 167, 'идет,': 168, 'Словно': 169, 'горькая': 170, 'вдовица,': 171, 'растет': 172, 'ребенок': 173, 'там': 174, 'День.прошел': 175, 'вопит...': 176, '"Ты,': 177, 'волна': 178, 'моя,': 179, 'волна?': 180, 'Плещешь': 181, 'ты,': 182, 'куда': 183, 'захочешь,': 184, 'Топишь': 185, 'берег': 186, 'ты': 187, 'земли,': 188, 'губи': 189, 'нашу': 190, 'душу:': 191, 'послушалась': 192, 'волна:': 193, 'Бочку': 194, 'вынесла': 195, 'легонько': 196, 'Мать': 197, 'младенцем': 198, 'спасена;': 199, 'Но': 200, 'бочки': 201, 'кто': 202, 'их': 203, 'вынет?': 204, 'Сын': 205, 'ножки': 206, 'поднялся,': 207, 'Понатужился': 208, 'немножко:': 209, 'Нам': 210, 'проделать?"': 211, 'молвил': 212, 'он,': 213, 'сын': 214, 'теперь': 215, 'воле;': 216, 'Море': 217, 'синее': 218, 'кругом,': 219, 'подумал:': 220, 'добрый': 221, 'ужин': 222, 'Ломит': 223, 'у': 224, 'дуба': 225, 'сук': 226, 'Со': 227, 'креста': 228, 'снурок': 229, 'шелковый': 230, 'Тонку': 231, 'тросточку': 232, 'сломил,': 233, 'пошел': 234, 'край': 235, 'долины': 236, 'К': 237, 'морю': 238, 'лишь': 239, 'подходит': 240, 'Видно,': 241, 'море': 242, 'тихо:': 243, 'Бьется': 244, 'лебедь': 245, 'средь': 246, 'зыбей,': 247, 'Та': 248, 'бедняжка': 249, 'так': 250, 'плещет,': 251, 'Тот': 252, 'уж': 253, 'когти': 254, 'распустил,': 255, 'раз': 256, 'стрела': 257, 'запела': 258, 'Коршун': 259, 'кровь': 260, 'пролил.': 261, 'Смотрит:': 262, 'коршун': 263, 'тонет': 264, 'Лебедь': 265, 'около': 266, 'плывет,': 267, 'Гибель': 268, 'близкую': 269, 'торопит,': 270, 'царевичу': 271, '"Ты': 272, 'царевич,': 273, 'мой': 274, 'спаситель,': 275, 'тужи,': 276, 'что': 277, 'меня': 278, 'Что': 279, 'пропала': 280, 'море;': 281, 'Отплачу': 282,  ...
# {0: 'Три', 1: 'девицы', 2: 'под', 3: 'окном', 4: '"Кабы', 5: 'я', 6: 'была', 7: 'царица,-', 8: 'То', 9: 'на', 10: 'весь', 11: 'крещеный', 12: 'мир', 13: '-', 14: 'бы', 15: 'одна', 16: 'Я', 17: 'б', 18: 'для', 19: 'батюшки-царя', 20: 'Только', 21: 'вымолвить', 22: 'успела,', 23: 'И', 24: 'в', 25: 'светлицу', 26: 'входит', 27: 'царь,', 28: 'Во', 29: 'все', 30: 'время', 31: 'разговора', 32: 'Речь', 33: 'последней', 34: 'по', 35: 'всему', 36: '"Здравствуй,', 37: 'красная', 38: 'девица,-', 39: 'роди', 40: 'богатыря', 41: 'Вы', 42: 'ж,', 43: 'голубушки-сестрицы,', 44: 'Поезжайте', 45: 'вслед', 46: 'за', 47: 'мной,', 48: 'Будь', 49: 'из', 50: 'вас', 51: 'ткачиха,', 52: 'В', 53: 'сени', 54: 'вышел', 55: 'царь-отец.', 56: 'Царь', 57: 'недолго', 58: 'собирался:', 59: 'Салтан', 60: 'пир', 61: 'честной', 62: 'А', 63: 'потом', 64: 'честные', 65: 'гости', 66: 'Положили', 67: 'молодых', 68: 'кухне', 69: 'злится', 70: 'повариха,', 71: 'завидуют', 72: 'оне', 73: 'царица', 74: 'молодая,', 75: 'С', 76: 'первой', 77: 'ночи', 78: 'понесла.', 79: 'Салтан,', 80: 'с', 81: 'женой', 82: 'простяся,', 83: 'Ей', 84: 'наказывал', 85: 'себя', 86: 'Между', 87: 'тем,', 88: 'как', 89: 'он', 90: 'далеко', 91: 'Наступает', 92: 'срок', 93: 'родин;', 94: 'над', 95: 'ребенком,', 96: 'Шлет', 97: 'письмом', 98: 'она', 99: 'гонца,', 100: 'ткачиха', 101: 'поварихой,', 102: 'Извести', 103: 'ее', 104: 'хотят,', 105: 'Сами', 106: 'шлют', 107: 'гонца', 108: 'другого', 109: '"Родила', 110: 'ночь', 111: 'Не', 112: 'мышонка,', 113: 'не', 114: 'лягушку,', 115: 'Как', 116: 'услышал', 117: 'царь-отец,', 118: 'гневе', 119: 'начал', 120: 'чудесить', 121: 'Но,', 122: 'смягчившись', 123: 'сей', 124: 'раз,', 125: '"Ждать', 126: 'царева', 127: 'возвращенья', 128: 'Едет', 129: 'грамотой', 130: 'гонец', 131: 'поварихой', 132: 'Обобрать', 133: 'его', 134: 'велят;', 135: 'суму', 136: 'пустую', 137: 'привез', 138: 'хмельной', 139: '"Царь', 140: 'велит', 141: 'своим', 142: 'боярам,', 143: 'царицу', 144: 'и', 145: 'приплод', 146: 'Делать', 147: 'нечего:', 148: 'бояре,', 149: 'царице', 150: 'молодой,', 151: 'Объявили', 152: 'царску', 153: 'волю', 154: 'Прочитали', 155: 'вслух', 156: 'указ', 157: 'бочку', 158: 'сыном', 159: 'посадили,', 160: 'пустили', 161: 'Окиян', 162: 'синем', 163: 'небе', 164: 'звезды', 165: 'блещут,', 166: 'Туча', 167: 'небу', 168: 'идет,', 169: 'Словно', 170: 'горькая', 171: 'вдовица,', 172: 'растет', 173: 'ребенок', 174: 'там', 175: 'День.прошел', 176: 'вопит...', 177: '"Ты,', 178: 'волна', 179: 'моя,', 180: 'волна?', 181: 'Плещешь', 182: 'ты,', 183: 'куда', 184: 'захочешь,', 185: 'Топишь', 186: 'берег', 187: 'ты', 188: 'земли,', 189: 'губи', 190: 'нашу', 191: 'душу:', 192: 'послушалась', 193: 'волна:', 194: 'Бочку', 195: 'вынесла', 196: 'легонько', 197: 'Мать', 198: 'младенцем', 199: 'спасена;', 200: 'Но', 201: 'бочки', 202: 'кто', 203: 'их', 204: 'вынет?', 205: 'Сын', 206: 'ножки', 207: 'поднялся,', 208: 'Понатужился', 209: 'немножко:', 210: 'Нам', 211: 'проделать?"', 212: 'молвил', 213: 'он,', 214: 'сын', 215: 'теперь', 216: 'воле;', 217: 'Море', 218: 'синее', 219: 'кругом,', 220: 'подумал:', 221: 'добрый', 222: 'ужин', 223: 'Ломит', 224: 'у', 225: 'дуба', 226: 'сук', 227: 'Со', 228: 'креста', 229: 'снурок', 230: 'шелковый', 231: 'Тонку', 232: 'тросточку', 233: 'сломил,', 234: 'пошел', 235: 'край', 236: 'долины', 237: 'К', 238: 'морю', 239: 'лишь', 240: 'подходит', 241: 'Видно,', 242: 'море', 243: 'тихо:', 244: 'Бьется', 245: 'лебедь', 246: 'средь', 247: 'зыбей,', 248: 'Та', 249: 'бедняжка', 250: 'так', 251: 'плещет,', 252: 'Тот', 253: 'уж', 254: 'когти', 255: 'распустил,', 256: 'раз', 257: 'стрела', 258: 'запела', 259: 'Коршун', 260: 'кровь', 261: 'пролил.', 262: 'Смотрит:', 263: 'коршун', 264: 'тонет', 265: 'Лебедь', 266: 'около', 267: 'плывет,', 268: 'Гибель', 269: 'близкую', 270: 'торопит,', 271: 'царевичу', 272: '"Ты', 273: 'царевич,', 274: 'мой', 275: 'спаситель,', 276: 'тужи,', 277: 'что', 278: 'меня', 279: 'Что', 280: 'пропала', 281: 'море;', 282: 'Отплачу',  ...
# 8544

# %%
class TextDataset(Dataset):
    def __init__(self, samples, word_to_int):
        self.samples = samples
        self.word_to_int = word_to_int
    def __len__(self):
        return len(self.samples)
    def __getitem__(self, idx):
        sample = self.samples[idx]
        input_seq = torch.LongTensor([self.word_to_int[word] for word in sample[:-1]])
        target_seq = torch.LongTensor([self.word_to_int[word] for word in sample[1:]])
        return input_seq, target_seq

# %%
dataset = TextDataset(samples, word_to_int)
dataloader = DataLoader(
    dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
)

# %%
def generate_square_subsequent_mask(sz):
    """
    Generate a square mask for the sequence. The masked positions are filled with float('-inf').
    Unmasked positions are filled with float(0.0).
    """
    mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask


class PositionalEncoding(nn.Module):
    def __init__(self, max_len, d_model, dropout=0.1):
        """
        :param max_len: Input length sequence.
        :param d_model: Embedding dimension.
        :param dropout: Dropout value (default=0.1)
        """
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
    def forward(self, x):
        """
        Inputs of forward function
        :param x: the sequence fed to the positional encoder model (required).
        Shape:
            x: [sequence length, batch size, embed dim]
            output: [sequence length, batch size, embed dim]
        """
        x = x + self.pe[:, :x.size(1)]
        return self.dropout(x)

# %%
class TextGen(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_layers, num_heads):
        super(TextGen, self).__init__()
        self.pos_encoder = PositionalEncoding(max_len=SEQUENCE_LENGTH, d_model=embed_dim)
        self.emb = nn.Embedding(vocab_size, embed_dim)
        self.decoder_layer = nn.TransformerDecoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            batch_first=True
        )
        self.decoder = nn.TransformerDecoder(
            decoder_layer=self.decoder_layer,
            num_layers=num_layers,
        )
        self.linear = nn.Linear(embed_dim, vocab_size)
        self.dropout = nn.Dropout(0.2)

    # Positional encoding is required. Else the model does not learn.
    def forward(self, x):
        emb = self.emb(x)

        # Generate input sequence mask with shape (SEQUENCE_LENGTH, SEQUENCE_LENGTH)
        input_mask = generate_square_subsequent_mask(x.size(1)).to(x.device)

        x = self.pos_encoder(emb)
        x = self.decoder(x, memory=x, tgt_mask=input_mask, memory_mask=input_mask)
        x = self.dropout(x)
        out = self.linear(x)
        return out

# %%
learning_rate = 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = TextGen(
    vocab_size=vocab_size,
    embed_dim=20,
    num_layers=2,
    num_heads=2,
).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# Total parameters and trainable parameters.
total_params = sum(p.numel() for p in model.parameters())
print(f"{total_params:,} total parameters.")
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f"{total_trainable_params:,} training parameters.\n")
# Out:
# 612,708 total parameters.
# 612,708 training parameters.

# %%
def train(model, epochs, dataloader, criterion):
    model.train()
    for epoch in range(epochs):
        running_loss = 0
        for input_seq, target_seq in dataloader:
            input_seq, target_seq = input_seq.to(device), target_seq.to(device)
            outputs = model(input_seq)
            target_seq = target_seq.contiguous().view(-1)
            outputs = outputs.view(-1, vocab_size)

            loss = criterion(outputs, target_seq.view(-1))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.detach().cpu().numpy()
        epoch_loss = running_loss / len(dataloader)
        print(f"Epoch {epoch} loss: {epoch_loss:.3f}")

t1 = time()
train(model, epochs, dataloader, criterion)
print("Training time:", time() - t1)
# Out:
# Epoch 0 loss: 7.490
# Epoch 1 loss: 5.333
# Epoch 2 loss: 4.268
# Epoch 3 loss: 3.736
# Epoch 4 loss: 3.383
# Epoch 5 loss: 3.122
# Epoch 6 loss: 2.912
# Epoch 7 loss: 2.741
# Epoch 8 loss: 2.589
# Epoch 9 loss: 2.457
# Epoch 10 loss: 2.338
# Epoch 11 loss: 2.236
# Epoch 12 loss: 2.137
# Epoch 13 loss: 2.051
# Epoch 14 loss: 1.971
# Epoch 15 loss: 1.901
# Epoch 16 loss: 1.832
# Epoch 17 loss: 1.773
# Epoch 18 loss: 1.715
# Epoch 19 loss: 1.661
# Training time: 5791.59267783165

# %%
def return_int_vector(text):
    words = text.split()
    input_seq = torch.LongTensor([word_to_int[word] for word in words[-SEQUENCE_LENGTH:]]).unsqueeze(0)
    return input_seq


def sample_next(predictions):
    """
    Greedy sampling.
    """
    # Greedy approach.
    probabilities = F.softmax(predictions[:, -1, :], dim=-1).cpu()
    next_token = torch.argmax(probabilities)
    return int(next_token.cpu())


def text_generator(sentence, generate_length):
    model.eval()
    sample = sentence
    for i in range(generate_length):
        int_vector = return_int_vector(sample)
        if len(int_vector) >= SEQUENCE_LENGTH - 1:
            break
        input_tensor = int_vector.to(device)
        with torch.no_grad():
            predictions = model(input_tensor)
        next_token = sample_next(predictions)
        sample += ' ' + int_to_word[next_token]
    print(sample)
    print('\n')

# %%
sentences = [
    "Я помню чудное "
]
generate_length = 200
for sentence in sentences:
    print(f"PROMPT: {sentence}")
    text_generator(sentence, generate_length)
# Out:
# PROMPT: Я помню чудное
# Я помню чудное  мгновенье: Как совершенства образец. Всегда неправедно гонимый, И привлекательным лицом. Всегда восторженный герой И привлекательным лицом. Всегда восторженный герой И при конце последней части Добру достойный был венок. Мораль на нас наводит сон, И тихо край земли светлеет, И тихо край земли светлеет, И в Лете не потонет Быть может быть, такого пира; Да спокойно в свой удел Князь у синя моря ходит, Глядь - поверх текучих вод "Здравствуй, князь Гвидон ей отвечает: Диво б дивное хотел он уж в лесу, под елью белка; Белка песенки поет А орешки не простые, Ядра - чистый изумруд; Там у князя женка есть, Днем свет божий затмевает, Месяц под косой блестит, А орешки не простые, Ядра - чистый изумруд; Там у князя женка есть, Днем свет божий затмевает, Месяц под косой блестит, А сама-то величава, А сама-то величава, А сама-то величава, А сама-то величава, А сама-то величава, А сама-то величава, А сама-то величава, А как речь-то говорит, Молвить можно справедливо. Гости умные молчат: Чуду царь Салтан дивится, И страшно тени густой Под ней жужжит, кружится - Коршун в лазоревой дали По равнинам Окияна Князь Гвидон сидит, Не шумит оно, не хлещет, И в лазоревой дали По равнинам Окияна Князь Гвидон сидит, Не шумит
